# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork1047-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
#
# # Non Linear Regression Analysis
#
#
# Estimated time needed: **20** minutes
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# * Differentiate between linear and non-linear regression
# * Use non-linear regression model in Python

# %% [markdown]
# If the data shows a curvy trend, then linear regression will not produce very accurate results when compared to a non-linear regression since linear regression presumes that the data is linear.
# Let's learn about non linear regressions and apply an example in python. In this notebook, we fit a non-linear model to the datapoints corrensponding to China's GDP from 1960 to 2014.

# %% [markdown]
# <h2 id="importing_libraries">Importing required libraries</h2>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Although linear regression can do a great job at modeling some datasets, it cannot be used for all datasets. First recall how linear regression, models a dataset. It models the linear relationship between a dependent variable y and the independent variables x. It has a simple equation, of degree 1, for example y = $2x$ + 3.

# %%
# FILE:BBundefined
#$#
# undefined
#$#

# Create an array x with values ranging from -5.0 to 5.0, with a step size of 0.1
x = np.arange(-5.0, 5.0, 0.1)

## You can adjust the slope and intercept to verify the changes in the graph
# Calculate the dependent variable y using a simple linear equation: y = 2x + 3
y = 2*(x) + 3

# Generate an array y_noise with random values from a normal distribution
# The size of y_noise is set to x.size, which is the number of elements in x
y_noise = 2 * np.random.normal(size=x.size)

# Add the noise to the original y values to create a new array ydata
ydata = y + y_noise

# Create a plot using Matplotlib
#plt.figure(figsize=(8,6))  # Uncomment to set a specific figure size
plt.plot(x, ydata,  'bo')  # Plot the noisy data points as blue circles
plt.plot(x, y, 'r')  # Plot the underlying linear relationship as a red line
plt.ylabel('Dependent Variable')  # Set the label for the y-axis
plt.xlabel('Independent Variable')  # Set the label for the x-axis
plt.show()  # Display the plot

# %%
y_noise
# Out:
# array([-3.08780242,  0.42248977, -1.38056396,  1.37862115,  4.00445337,
#         0.84081422,  1.66514454,  2.29988018, -1.23982948, -2.23505458,
#        -1.95437637,  1.9148207 ,  4.22806314,  1.14053864,  0.35034307,
#         2.51258832, -2.58995918, -1.81195888, -3.01234002,  1.37866115,
#        -0.72036511, -1.91270087,  0.41054876, -0.64315469,  1.16664384,
#        -1.92579624,  0.42868129,  0.74132509, -4.0020545 , -1.5193404 ,
#         0.60489526,  1.27868729, -1.05897219,  0.9087015 ,  0.85225254,
#        -2.28140724, -0.95218898,  2.5412835 , -1.14073565, -0.574194  ,
#        -0.01097513, -1.7567988 , -0.76732684, -0.53099117,  1.03981871,
#         1.45356573, -0.97205746,  2.61430655,  1.01351883, -4.12717165,
#        -0.59024967,  0.23764084,  0.1949692 , -3.30531875,  2.05597745,
#        -0.76486207, -0.04013796,  4.94173308,  2.66620468, -4.4949648 ,
#        -0.591592  , -0.3253596 ,  1.17370469,  1.51754564,  1.9705118 ,
# ...

# %% [markdown]
# Non-linear regression is a method to model the non-linear relationship between the independent variables $x$ and the dependent variable $y$. Essentially any relationship that is not linear can be termed as non-linear, and is usually represented by the polynomial of $k$ degrees (maximum power of $x$).  For example:
#
# $$ \ y = a x^3 + b x^2 + c x + d \ $$
#
# Non-linear functions can have elements like exponentials, logarithms, fractions, and so on. For example: $$ y = \log(x)$$
#
# We can have a function that's even more complicated such as :
# $$ y = \log(a x^3 + b x^2 + c x + d)$$

# %% [markdown]
# Let's take a look at a cubic function's graph.

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph
y = 1*(x**3) + 1*(x**2) + 1*x + 3
y_noise = 20 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# As you can see, this function has $x^3$ and $x^2$ as independent variables. Also, the graphic of this function is not a straight line over the 2D plane. So this is a non-linear function.

# %% [markdown]
# Some other types of non-linear functions are:

# %% [markdown]
# ### Quadratic

# %% [markdown]
# $$ Y = X^2 $$

# %%
x = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

y = np.power(x,2)
y_noise = 2 * np.random.normal(size=x.size)
ydata = y + y_noise
plt.plot(x, ydata,  'bo')
plt.plot(x,y, 'r') 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# ### Exponential

# %% [markdown]
# An exponential function with base c is defined by $$ Y = a + b c^X$$ where b ≠0, c > 0 , c ≠1, and x is any real number. The base, c, is constant and the exponent, x, is a variable.

# %%
X = np.arange(-5.0, 5.0, 0.1)

##You can adjust the slope and intercept to verify the changes in the graph

Y= np.exp(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# ### Logarithmic
#
# The response $y$ is a results of applying the logarithmic map from the input $x$ to the output $y$. It is one of the simplest form of __log()__: i.e. $$ y = \log(x)$$
#
# Please consider that instead of $x$, we can use $X$, which can be a polynomial representation of the $x$ values. In general form it would be written as
# \begin{equation}
# y = \log(X)
# \end{equation}

# %%
X = np.arange(-5.0, 5.0, 0.1)

Y = np.log(X)

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()
# Out:
# C:\Users\yasin\AppData\Local\Temp\ipykernel_25364\2233958358.py:3: RuntimeWarning: invalid value encountered in log
#   Y = np.log(X)

# %% [markdown]
# ### Sigmoidal/Logistic

# %% [markdown]
# $$ Y = a + \frac{b}{1+ c^{(X-d)}}$$

# %%
X = np.arange(-5.0, 5.0, 0.1)


Y = 1-4/(1+np.power(3, X-2))

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# <a id="ref2"></a>
# # Non-Linear Regression example

# %% [markdown]
# For an example, we're going to try and fit a non-linear model to the datapoints corresponding to China's GDP from 1960 to 2014. We download a dataset with two columns, the first, a year between 1960 and 2014, the second, China's corresponding annual gross domestic income in US dollars for that year.

# %%
import numpy as np
import pandas as pd

#downloading dataset
# !wget -nv -O china_gdp.csv https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%202/data/china_gdp.csv
    
df = pd.read_csv("china_gdp.csv")
df.head(10)
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10
# 5  1965  6.970915e+10
# 6  1966  7.587943e+10
# 7  1967  7.205703e+10
# 8  1968  6.999350e+10
# 9  1969  7.871882e+10

# %%
df = pd.read_csv("china_gdp.csv")
df.head(10)
# Out:
#    Year         Value
# 0  1960  5.918412e+10
# 1  1961  4.955705e+10
# 2  1962  4.668518e+10
# 3  1963  5.009730e+10
# 4  1964  5.906225e+10
# 5  1965  6.970915e+10
# 6  1966  7.587943e+10
# 7  1967  7.205703e+10
# 8  1968  6.999350e+10
# 9  1969  7.871882e+10

# %% [markdown]
# __Did you know?__ When it comes to Machine Learning, you will likely be working with large datasets. As a business, where can you host your data? IBM is offering a unique opportunity for businesses, with 10 Tb of IBM Cloud Object Storage: [Sign up now for free](http://cocl.us/ML0101EN-IBM-Offer-CC)

# %% [markdown]
# ### Plotting the Dataset ###
# This is what the datapoints look like. It kind of looks like an either logistic or exponential function. The growth starts off slow, then from 2005 on forward, the growth is very significant. And finally, it decelerates slightly in the 2010s.

# %%
plt.figure(figsize=(8,5))
x_data, y_data = (df["Year"].values, df["Value"].values)
plt.plot(x_data, y_data, 'bo')
plt.plot(x_data, y_data, 'r-')

plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %%
plt.figure(figsize=(8,5))
x_data, y_data = (df["Year"].values, df["Value"].values)
plt.plot(x_data, y_data, 'r-')
plt.ylabel('GDP')
plt.xlabel('Year')
plt.show()

# %%
x_data
# Out:
# array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#        1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#        1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#        1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#        2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014],
#       dtype=int64)

# %%
y_data
# Out:
# array([5.91841165e+10, 4.95570502e+10, 4.66851785e+10, 5.00973033e+10,
#        5.90622549e+10, 6.97091531e+10, 7.58794348e+10, 7.20570286e+10,
#        6.99934979e+10, 7.87188205e+10, 9.15062113e+10, 9.85620238e+10,
#        1.12159814e+11, 1.36769878e+11, 1.42254742e+11, 1.61162492e+11,
#        1.51627687e+11, 1.72349014e+11, 1.48382112e+11, 1.76856525e+11,
#        1.89649992e+11, 1.94369049e+11, 2.03549627e+11, 2.28950201e+11,
#        2.58082147e+11, 3.07479586e+11, 2.98805793e+11, 2.71349773e+11,
#        3.10722214e+11, 3.45957486e+11, 3.58973230e+11, 3.81454704e+11,
#        4.24934066e+11, 4.42874596e+11, 5.62261130e+11, 7.32032045e+11,
#        8.60844098e+11, 9.58159425e+11, 1.02527690e+12, 1.08944711e+12,
#        1.20526068e+12, 1.33223472e+12, 1.46190649e+12, 1.64992872e+12,
#        1.94174560e+12, 2.26859890e+12, 2.72978403e+12, 3.52309431e+12,
#        4.55843107e+12, 5.05941974e+12, 6.03965851e+12, 7.49243210e+12,
# ...

# %% [markdown]
# ### Choosing a model ###
#
# From an initial look at the plot, we determine that the logistic function could be a good approximation,
# since it has the property of starting with a slow growth, increasing growth in the middle, and then decreasing again at the end; as illustrated below:

# %%
X = np.arange(-5.0, 5.0, 0.1)
Y = 1.0 / (1.0 + np.exp(-X))

plt.plot(X,Y) 
plt.ylabel('Dependent Variable')
plt.xlabel('Independent Variable')
plt.show()

# %% [markdown]
# The formula for the logistic function is the following:
#
# $$ \hat{Y} = \frac1{1+e^{-\beta_1(X-\beta_2)}}$$
#
# $\beta_1$: Controls the curve's steepness,
#
# $\beta_2$: Slides the curve on the x-axis.

# %% [markdown]
# ### Building The Model ###
# Now, let's build our regression model and initialize its parameters.

# %%
def sigmoid(x, Beta_1, Beta_2):
     y = 1 / (1 + np.exp(-Beta_1*(x-Beta_2)))
     return y

# %% [markdown]
# Lets look at a sample sigmoid line that might fit with the data:

# %%
beta_1 = 0.10
beta_2 = 1990.0

#logistic function
Y_pred = sigmoid(x_data, beta_1 , beta_2)

#plot initial prediction against datapoints
plt.plot(x_data, Y_pred*15000000000000.)
plt.plot(x_data, y_data, 'ro')

# %% [markdown]
# ### Before normalization

# %%
x_data, y_data
# Out:
# (array([1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970,
#         1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981,
#         1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992,
#         1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003,
#         2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014],
#        dtype=int64),
#  array([5.91841165e+10, 4.95570502e+10, 4.66851785e+10, 5.00973033e+10,
#         5.90622549e+10, 6.97091531e+10, 7.58794348e+10, 7.20570286e+10,
#         6.99934979e+10, 7.87188205e+10, 9.15062113e+10, 9.85620238e+10,
#         1.12159814e+11, 1.36769878e+11, 1.42254742e+11, 1.61162492e+11,
#         1.51627687e+11, 1.72349014e+11, 1.48382112e+11, 1.76856525e+11,
#         1.89649992e+11, 1.94369049e+11, 2.03549627e+11, 2.28950201e+11,
#         2.58082147e+11, 3.07479586e+11, 2.98805793e+11, 2.71349773e+11,
#         3.10722214e+11, 3.45957486e+11, 3.58973230e+11, 3.81454704e+11,
# ...

# %% [markdown]
# Our task here is to find the best parameters for our model. Lets first normalize our x and y:

# %%
# Lets normalize our data
xdata =x_data/max(x_data)
ydata =y_data/max(y_data)

# %% [markdown]
# ### After normalization

# %%
xdata, ydata
# Out:
# (array([0.97318769, 0.97368421, 0.97418073, 0.97467726, 0.97517378,
#         0.97567031, 0.97616683, 0.97666336, 0.97715988, 0.97765641,
#         0.97815293, 0.97864945, 0.97914598, 0.9796425 , 0.98013903,
#         0.98063555, 0.98113208, 0.9816286 , 0.98212512, 0.98262165,
#         0.98311817, 0.9836147 , 0.98411122, 0.98460775, 0.98510427,
#         0.98560079, 0.98609732, 0.98659384, 0.98709037, 0.98758689,
#         0.98808342, 0.98857994, 0.98907646, 0.98957299, 0.99006951,
#         0.99056604, 0.99106256, 0.99155909, 0.99205561, 0.99255214,
#         0.99304866, 0.99354518, 0.99404171, 0.99453823, 0.99503476,
#         0.99553128, 0.99602781, 0.99652433, 0.99702085, 0.99751738,
#         0.9980139 , 0.99851043, 0.99900695, 0.99950348, 1.        ]),
#  array([0.0057156 , 0.00478589, 0.00450854, 0.00483806, 0.00570384,
#         0.00673204, 0.00732793, 0.00695878, 0.0067595 , 0.00760213,
#         0.00883705, 0.00951846, 0.01083164, 0.01320831, 0.01373801,
# ...

# %% [markdown]
# #### How we find the best parameters for our fit line?
# we can use __curve_fit__ which uses non-linear least squares to fit our sigmoid function, to data. Optimize values for the parameters so that the sum of the squared residuals of sigmoid(xdata, *popt) - ydata is minimized.
#
# popt are our optimized parameters.

# %%
# Import the curve_fit function from the scipy.optimize module
# This function is used to fit a given function to a set of data points
from scipy.optimize import curve_fit

# Assume that sigmoid, xdata, and ydata are already defined:

# sigmoid: the function we want to fit to the data
# xdata: the independent variable data 
# ydata: the dependent variable data 

# Fit the sigmoid function to the data using curve_fit
# curve_fit attempts to find the parameters (beta_1, beta_2, ...) 
# that make the sigmoid function best fit the data

# popt: array of optimal values for the parameters
# pcov: 2D array representing the estimated covariance of popt
popt, pcov = curve_fit(sigmoid, xdata, ydata)

# Print the final parameters of the sigmoid function
# The %f format specifier indicates that the values will be printed as floating-point numbers
# popt[0] and popt[1] correspond to the fitted values for beta_1 and beta_2, respectively
print(" beta_1 = %f, beta_2 = %f" % (popt[0], popt[1]))
# Out:
#  beta_1 = 690.451712, beta_2 = 0.997207

# %%
popt
# Out:
# array([690.45171182,   0.99720713])

# %%
pcov,
# Out:
# (array([[ 1.52271494e+03, -2.88118935e-04],
#         [-2.88118935e-04,  7.25961451e-09]]),)

# %% [markdown]
# Now we plot our resulting regression model.

# %%
# Create an array of 55 evenly spaced values from year 1960 to 2015
x = np.linspace(1960, 2015, 55)

# Normalize x values to be between 0 and 1
x = x / max(x)

# Create a new figure with a specified size
plt.figure(figsize=(8,5))

# Calculate sigmoid values using normalized x and optimal parameters
y = sigmoid(x, *popt)

# Plot original data points with red circles
plt.plot(xdata, ydata, 'ro', label='data')

# Plot sigmoid fit curve with a line width of 3.0
plt.plot(x, y, linewidth=3.0, label='fit')

# Add a legend with automatic placement
plt.legend(loc='best')

# Set y-axis label to "GDP"
plt.ylabel('GDP')

# Set x-axis label to "Year"
plt.xlabel('Year')

# Display the plot
plt.show()

# %% [markdown]
# ## Practice
# Can you calculate what is the accuracy of our model?

# %%
# write your code here

from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# # split data into train/test
# msk = np.random.rand(len(df)) < 0.8
# train_x = xdata[msk]
# test_x = xdata[~msk]
# train_y = ydata[msk]
# test_y = ydata[~msk]
#
# # build the model using train set
# popt, pcov = curve_fit(sigmoid, train_x, train_y)
#
# # predict using test set
# y_hat = sigmoid(test_x, *popt)
#
# # evaluation
# print("Mean absolute error: %.2f" % np.mean(np.absolute(y_hat - test_y)))
# print("Residual sum of squares (MSE): %.2f" % np.mean((y_hat - test_y) ** 2))
# from sklearn.metrics import r2_score
# print("R2-score: %.2f" % r2_score(test_y,y_hat) )
#
# ```
#
# </details>

# %%
from sklearn.model_selection import train_test_split
from scipy.optimize import curve_fit
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Define your sigmoid function
def sigmoid(x, a, b, c):
    # Sigmoid function with parameters a, b, and c
    return a / (1.0 + np.exp(-b * (x - c)))

# Split the data into training and testing sets
# x_train, x_test: features for training and testing
# y_train, y_test: labels for training and testing
x_train, x_test, y_train, y_test = train_test_split(xdata, ydata, test_size=0.2, random_state=42)

# Convert data to numpy arrays (if not already in that format)
x_train = np.array(x_train)
x_test = np.array(x_test)
y_train = np.array(y_train)
y_test = np.array(y_test)

# Normalize the training and testing feature data
# Normalization helps to avoid overflow in the exponential function
x_train_normalized = (x_train - np.mean(x_train)) / np.std(x_train)
x_test_normalized = (x_test - np.mean(x_train)) / np.std(x_train)

# Provide an initial guess for the sigmoid function parameters to help the optimizer
initial_guess = [1, 1, 1]

# Fit the sigmoid function to the training data
# popt: optimal values for the parameters
# pcov: the estimated covariance of popt
popt, pcov = curve_fit(sigmoid, x_train_normalized, y_train, p0=initial_guess)

# Use the fitted sigmoid function to predict the labels of the test data
y_hat = sigmoid(x_test_normalized, *popt)

# Calculate evaluation metrics
mae = mean_absolute_error(y_test, y_hat)
mse = mean_squared_error(y_test, y_hat)
r2 = r2_score(y_test, y_hat)
print("Predicted values:\n", y_hat)
# Print the predicted values and evaluation metrics
print("\n  evaluation metrics:\n")

print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared (R²):", r2)
# Out:
# Predicted values:
#  [2.51726906e-02 3.03608956e-04 2.98151796e-02 1.18353167e-03
#  3.28260112e-03 4.92941950e-01 1.35210350e-01 1.07821885e-02
#  1.88169665e-01 9.98452705e-04 7.75998967e-01]
#
#   evaluation metrics:
#
# Mean Absolute Error (MAE): 0.014903022598907419
# Mean Squared Error (MSE): 0.0003317639810286776
# R-squared (R²): 0.9945939186732548

# %% [markdown]
# <h2>Want to learn more?</h2>
#
# IBM SPSS Modeler is a comprehensive analytics platform that has many machine learning algorithms. It has been designed to bring predictive intelligence to decisions made by individuals, by groups, by systems – by your enterprise as a whole. A free trial is available through this course, available here: <a href="https://www.ibm.com/analytics/spss-statistics-software?utm_source=Exinfluencer&utm_content=000026UJ&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork1047-2023-01-01&utm_medium=Exinfluencer&utm_term=10006555">SPSS Modeler</a>
#
# Also, you can use Watson Studio to run these notebooks faster with bigger datasets. Watson Studio is IBM's leading cloud solution for data scientists, built by data scientists. With Jupyter notebooks, RStudio, Apache Spark and popular libraries pre-packaged in the cloud, Watson Studio enables data scientists to collaborate on their projects without having to install anything. Join the fast-growing community of Watson Studio users today with a free account at <a href="https://www.ibm.com/cloud/watson-studio?utm_source=Exinfluencer&utm_content=000026UJ&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork1047-2023-01-01&utm_medium=Exinfluencer&utm_term=10006555">Watson Studio</a>

# %% [markdown]
# ### Thank you for completing this lab!
#
#
# ## Author
#
# Saeed Aghabozorgi
#
#
# ### Other Contributors
#
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork1047-2023-01-01">Joseph Santarcangelo</a>
#
#
#
#
# ## Change Log
#
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-11-03  | 2.1 | Lakshmi |  Made changes in URL |
# | 2020-08-27  | 2.0  | Lavanya  |  Moved lab to course repo in GitLab |
# |   |   |   |   |
# |   |   |   |   |
#
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
